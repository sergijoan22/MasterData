# %% [markdown]
# Notebook inicial

# %%
import datetime
import time

# %%
i = 0
while i < 10:
  now = datetime.datetime.now()
  print(now.year, now.month, now.day, now.hour+2, now.minute, now.second)
  time.sleep(1)
  i = i + 1
# Out:
# 2021 10 16 9 55 24
# 2021 10 16 9 55 25
# 2021 10 16 9 55 26
# 2021 10 16 9 55 27
# 2021 10 16 9 55 28
# 2021 10 16 9 55 29
# 2021 10 16 9 55 30
# 2021 10 16 9 55 31
# 2021 10 16 9 55 32
# 2021 10 16 9 55 33
